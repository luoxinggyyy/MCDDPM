# %%
import numpy as np
import torch
import pandas as pd
from plotnine import ggplot, aes, geom_line,geom_point,ggsave

# %%
b = pd.read_csv('np_to_csv.csv').dropna()

# %%
ggplot(b, aes(x='epoch', y='loss'))+ geom_line(color="#32CD32")
# Out:
# <ggplot: (91771465903)>

# %%
p = ggplot(b, aes(x='epoch', y='loss'))+ geom_line(color="#32CD32")
ggsave(plot=p, filename='test.eps', dpi=600)
# Out:
# d:\anaconda\envs\pytorch\lib\site-packages\plotnine\ggplot.py:718: PlotnineWarning: Saving 6.4 x 4.8 in image.
# d:\anaconda\envs\pytorch\lib\site-packages\plotnine\ggplot.py:719: PlotnineWarning: Filename: test.eps

# %%
c = pd.read_csv('FID.csv').dropna()

# %%
ggplot(c, aes(x='num_train', y='FID',color='label'))+ geom_line(size=1,)
# Out:
# <ggplot: (133663560084)>
